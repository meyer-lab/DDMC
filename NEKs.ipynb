# %%
from msresist.figures.figure3 import plot_siRNA_TimeLapse
import matplotlib.pyplot as plt

_, ax = plt.subplots(1, 2, figsize=(10, 5))
plot_siRNA_TimeLapse(ax, "NEK6", time=96, itp=24, trs=3)

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5))
plot_siRNA_TimeLapse(ax, "NEK7", time=96, itp=24, trs=3)
