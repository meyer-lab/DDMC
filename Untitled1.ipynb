# %%
import pandas as pd
from msresist.FileExporter import create_download_link

# %%
raw1 = pd.read_csv("./msresist/data/Raw/20180817_JG_AM_TMT10plex_R1_psms_raw.csv")
raw2 = pd.read_csv("./msresist/data/Raw/20190214_JG_AM_PC9_AXL_TMT10_AC28_R2_PSMs_raw.csv")
raw3 = pd.read_csv("./msresist/data/Raw/CombinedBR3_TR1&2_raw.csv")

# %%
prot_accs = list(raw3.iloc[:, 2])
prot_names = list(raw3.iloc[:, 1])

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', 1000)

newacc = [acc.split(";")[0] for _, acc in enumerate(prot_accs)]
newnames = [prot.split("|")[0] for _, prot in enumerate(prot_names)]

# %%
raw3.iloc[:, 2] = newacc
raw3.iloc[:, 1] = newnames

# %%
create_download_link(raw2, "CombinedBR3_TR1&2_raw.csv")
# Out:
# <a download="CombinedBR3_TR1&2_raw.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
