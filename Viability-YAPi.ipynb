# %% [markdown]
# # YAP INHIBITORS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from msresist.figures.figure1 import TimePointFoldChange
from msresist.figures.figure4 import transform_YAPviability_data, plot_YAPinhibitorTimeLapse

# %%
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 1000)

# %%
sns.set(style="whitegrid", font_scale=1.1, color_codes=True, palette="colorblind", rc={"grid.linestyle": "dotted", "axes.linewidth": 0.6})

# %% [markdown]
# ## Untreated

# %%
ut = pd.read_csv("msresist/data/Validations/0nM.csv")

fig, ax = plt.subplots(2, 4, figsize=(15, 7))
plt.subplots_adjust(wspace=0.3, hspace=0.35)

ut = transform_YAPviability_data([ut])
plot_YAPinhibitorTimeLapse(ax, ut)

# %% [markdown]
# ## Imatinib

# %%
im1 = pd.read_csv("msresist/data/Validations/Imatinib.csv")
im2 = pd.read_csv("msresist/data/Validations/Imatinib_2fixed.csv")
im = [im1, im2]

fig, ax = plt.subplots(2, 4, figsize=(15, 7), sharey=True)
plt.subplots_adjust(wspace=0.3, hspace=0.35)

im = transform_YAPviability_data(im, itp=24)
plot_YAPinhibitorTimeLapse(ax, im)

# %% [markdown]
# ## Dasatinib

# %%
das1 = pd.read_csv("msresist/data/Validations/Dasatinib.csv")
das2 = pd.read_csv("msresist/data/Validations/Dasatinib_2fixed.csv")
das = [das1, das2]

fig, ax = plt.subplots(2, 4, figsize=(15, 7), sharey=True)
plt.subplots_adjust(wspace=0.3, hspace=0.35)

das = transform_YAPviability_data(das)
plot_YAPinhibitorTimeLapse(ax, das)

# %% [markdown]
# ## NSC 319726

# %%
nsc1 = pd.read_csv("msresist/data/Validations/NSC.csv")
nsc2 = pd.read_csv("msresist/data/Validations/NSC_2fixed.csv")
nsc = [nsc1, nsc2]

fig, ax = plt.subplots(2, 4, figsize=(15, 7), sharey=True)
plt.subplots_adjust(wspace=0.3, hspace=0.35)

nsc = transform_YAPviability_data(nsc)
plot_YAPinhibitorTimeLapse(ax, nsc)

# %% [markdown]
# ## THZ2

# %%
thz1 = pd.read_csv("msresist/data/Validations/THZ2.csv")
thz2 = pd.read_csv("msresist/data/Validations/THZ2_2fixed.csv")
thz = [thz1, thz2]

fig, ax = plt.subplots(2, 4, figsize=(15, 7), sharey=True)
plt.subplots_adjust(wspace=0.3, hspace=0.35)

thz = transform_YAPviability_data(thz)
plot_YAPinhibitorTimeLapse(ax, thz)

# %% [markdown]
# ## YM155

# %%
ym1 = pd.read_csv("msresist/data/Validations/YM155_first.csv")
ym2 = pd.read_csv("msresist/data/Validations/YM155_2fixed.csv")
ym = [ym1, ym2]

fig, ax = plt.subplots(2, 4, figsize=(15, 7), sharey=True)
plt.subplots_adjust(wspace=0.3, hspace=0.35)

ym = transform_YAPviability_data(ym)
plot_YAPinhibitorTimeLapse(ax, ym)
