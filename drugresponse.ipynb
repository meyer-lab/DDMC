# %% [markdown]
# ## DRUG RESPONSE CLEAN UP

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from msresist.figures.figure3 import plot_siRNA_TimeLapse, plotHyerGeomTestDasDRGenes, plot_dasatinib_MS_clustermaps

# %%
# Set plotting format
matplotlib.rcParams['font.sans-serif'] = "Arial"
sns.set(style="whitegrid", font_scale=1, color_codes=True, palette="colorblind", rc={"grid.linestyle": "dotted", "axes.linewidth": 0.6})

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5))
plot_siRNA_TimeLapse(ax, "NEK6", time=96, itp=24, trs=5)

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5))
plot_siRNA_TimeLapse(ax, "NEK7", time=96, itp=24, trs=5)
