# %%
import pickle 
import pandas as pd
import numpy as np

with open('msresist/data/pickled_models/binomial/CPTACmodel_BINOMIAL_CL24_W15_TMT2', 'rb') as p:
    model = pickle.load(p)[0]

# %%
from msresist.pre_processing import filter_NaNpeptides

X = pd.read_csv("msresist/data/MS/CPTAC/CPTAC-preprocessedMotfis.csv").iloc[:, 1:]
X = filter_NaNpeptides(X, tmt=2)

# %%
X["Cluster"] = model.labels()

# %%
X[X["Gene"] == "SLK"].sort_values(by="Cluster")
# Out:
#           Sequence         Protein Gene              Position  C3N.01799  \
# 2571   ASSDLsIASSE  NP_001291672.1  SLK                S344-p        NaN
# 4572   DLSIAsSEEDK  NP_001291672.1  SLK                S347-p        NaN
# 38021  TKDSGsISLQE  NP_001291672.1  SLK                S779-p  -0.054522
# 2423   ASKRAsSDLSI  NP_001291672.1  SLK                S340-p        NaN
# 2426   ASKRAssDLsI  NP_001291672.1  SLK  S340-p;S341-p;S344-p        NaN
# 34444  SKTKDsGsISL  NP_001291672.1  SLK         S777-p;S779-p        NaN
# 34443  SKTKDsGSISL  NP_001291672.1  SLK                S777-p        NaN
# 39269  TVDLVsQETGE  NP_001291672.1  SLK                S503-p        NaN
# 31382  RPRKKtLEEEF  NP_001291672.1  SLK               T1188-p        NaN
# 33380  SDVIGtCEAAD  NP_001291672.1  SLK                T551-p        NaN
# 14426  IQAVDsEVGLT  NP_001291672.1  SLK                S518-p   0.328939
# 2424   ASKRAsSDLsI  NP_001291672.1  SLK         S340-p;S344-p   0.429552
# 34383  SKRASsDLsIA  NP_001291672.1  SLK         S341-p;S344-p   0.429552
# 34382  SKRASsDLSIA  NP_001291672.1  SLK                S341-p        NaN
# 15960  KIVTDsDSKTE  NP_001291672.1  SLK                S816-p        NaN
# 38966  TSKIVtDSDSK  NP_001291672.1  SLK                T814-p        NaN
# 516    AEDTQsNDGKE  NP_001291672.1  SLK                S571-p        NaN
# 17630  KVDEDsAEDTQ  NP_001291672.1  SLK                S565-p   1.397479
# 5081   DSAEDtQsNDG  NP_001291672.1  SLK         T569-p;S571-p        NaN
# 5080   DSAEDtQSNDG  NP_001291672.1  SLK                T569-p        NaN
# 2425   ASKRAssDLSI  NP_001291672.1  SLK         S340-p;S341-p        NaN
# 9174   FIGTPyWMAPE  NP_001291672.1  SLK                Y195-p        NaN
# 41214  VTDSDsKTEEL  NP_001291672.1  SLK                S818-p        NaN
# 7475   EMEVRsVVADT  NP_001291672.1  SLK                S655-p  -0.244274
# 6169   EEDKLsQNACI  NP_001291672.1  SLK                S354-p        NaN
# 4573   DLSIAssEEDK  NP_001291672.1  SLK         S347-p;S348-p        NaN
# 17631  KVDEDsAEDtQ  NP_001291672.1  SLK         S565-p;T569-p  -0.692760
#
#        C3N.01799.N  C3L.01890  C3L.01890.N  C3N.00572  C3N.00572.N  ...  \
# 2571           NaN        NaN          NaN        NaN          NaN  ...
# 4572           NaN        NaN          NaN        NaN          NaN  ...
# 38021     0.072227  -0.995614     0.304094   0.399501     1.173516  ...
# 2423           NaN        NaN          NaN        NaN          NaN  ...
# 2426           NaN        NaN          NaN        NaN          NaN  ...
# 34444          NaN        NaN          NaN        NaN          NaN  ...
# 34443          NaN        NaN          NaN        NaN          NaN  ...
# 39269          NaN        NaN          NaN        NaN          NaN  ...
# 31382          NaN        NaN          NaN        NaN          NaN  ...
# 33380          NaN        NaN          NaN        NaN          NaN  ...
# 14426     0.043824  -0.275206     1.310499   0.209523     0.705989  ...
# 2424     -1.256682  -0.119975    -0.597802   0.390728    -0.599684  ...
# 34383    -1.256682  -0.119975    -0.597802   0.390728    -0.599684  ...
# 34382          NaN        NaN          NaN        NaN          NaN  ...
# 15960          NaN        NaN          NaN        NaN          NaN  ...
# 38966          NaN        NaN          NaN        NaN          NaN  ...
# 516            NaN        NaN          NaN        NaN          NaN  ...
# 17630    -0.324735  -0.184032    -1.182936   0.817491    -0.206215  ...
# 5081           NaN        NaN          NaN        NaN          NaN  ...
# 5080           NaN        NaN          NaN        NaN          NaN  ...
# 2425           NaN        NaN          NaN        NaN          NaN  ...
# 9174           NaN        NaN          NaN        NaN          NaN  ...
# 41214          NaN        NaN          NaN        NaN          NaN  ...
# 7475     -0.503537   1.855634     0.170479  -0.158897    -0.068445  ...
# 6169           NaN        NaN          NaN        NaN          NaN  ...
# 4573           NaN        NaN          NaN        NaN          NaN  ...
# 17631    -0.787172   0.047229    -0.569527  -0.454863    -0.978033  ...
#
#        C3N.02379.N  C3N.00175  C3N.00175.N  C3N.01823  C3N.01823.N  C3L.02549  \
# 2571           NaN   0.185661    -0.485451  -0.186588    -3.416690   2.129797
# 4572           NaN        NaN          NaN        NaN          NaN        NaN
# 38021    -0.123447   0.222860    -2.050081   0.535986    -1.099279  -0.358124
# 2423           NaN  -0.128876    -0.723477   1.034646     0.318165   1.901797
# 2426           NaN        NaN          NaN        NaN          NaN        NaN
# 34444          NaN        NaN          NaN        NaN          NaN        NaN
# 34443          NaN   0.222860    -2.050081   0.535986    -1.099279  -0.358124
# 39269          NaN        NaN          NaN        NaN          NaN        NaN
# 31382          NaN        NaN          NaN        NaN          NaN        NaN
# 33380     0.217257   0.341743    -0.114561   0.872159     0.038618   1.950329
# 14426    -1.509075  -0.192679    -1.190991  -0.911940    -1.270030   0.874285
# 2424           NaN        NaN          NaN        NaN          NaN        NaN
# 34383          NaN        NaN          NaN        NaN          NaN        NaN
# 34382          NaN        NaN          NaN        NaN          NaN        NaN
# 15960          NaN        NaN          NaN        NaN          NaN        NaN
# 38966          NaN        NaN          NaN        NaN          NaN        NaN
# 516      -0.671664   0.178244    -0.695069  -0.082839    -0.665122   0.963051
# 17630    -0.636778  -0.162814    -0.803434  -0.263327    -0.231847   1.281479
# 5081           NaN        NaN          NaN        NaN          NaN        NaN
# 5080     -0.734390   0.362732    -0.811869  -0.328701    -0.312920   1.138070
# 2425           NaN   0.049741    -0.036531   0.575090     0.520377   1.282447
# 9174           NaN        NaN          NaN        NaN          NaN        NaN
# 41214          NaN        NaN          NaN        NaN          NaN        NaN
# 7475           NaN   0.676987    -1.157771  -0.059293    -0.545305   0.311142
# 6169           NaN        NaN          NaN        NaN          NaN        NaN
# 4573     -0.731722  -0.219262    -0.042565  -0.184065    -0.350931   1.170966
# 17631          NaN        NaN          NaN        NaN          NaN        NaN
#
#        C3L.02549.N  C3L.02365  C3L.02365.N  Cluster
# 2571     -1.840761  -1.176955    -2.273628        2
# 4572           NaN        NaN          NaN        2
# 38021    -0.590079   0.047249    -0.646506        3
# 2423     -0.186134   2.397948    -0.150309        6
# 2426           NaN        NaN          NaN        6
# 34444          NaN        NaN          NaN        6
# 34443    -0.590079   0.047249    -0.646506        6
# 39269          NaN        NaN          NaN        6
# 31382          NaN        NaN          NaN        6
# 33380     0.259262   0.378941     0.253870        7
# 14426    -1.468675  -0.751307    -0.209159        8
# 2424           NaN        NaN          NaN       14
# 34383          NaN        NaN          NaN       14
# 34382          NaN        NaN          NaN       14
# 15960          NaN        NaN          NaN       16
# 38966          NaN        NaN          NaN       17
# 516      -0.446406   0.541243    -0.252286       17
# 17630     0.020092   0.273588    -0.326594       17
# 5081           NaN        NaN          NaN       17
# 5080      0.110871   0.567632    -0.232910       17
# 2425     -0.446409  -0.250692    -0.318640       17
# 9174           NaN        NaN          NaN       18
# 41214          NaN        NaN          NaN       19
# 7475     -0.360066   0.352090    -0.441736       20
# 6169           NaN        NaN          NaN       20
# 4573     -0.643266   0.482974    -0.920511       20
# 17631          NaN        NaN          NaN       20
#
# [27 rows x 220 columns]
