# %%
from Estimator import *
from PLSR_functions import FilteringOutPeptides
from sklearn.model_selection import LeaveOneOut
import scipy as sp, numpy as np, pandas as pd, math
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import warnings
warnings.simplefilter("ignore")

# %%
X = np.array(pd.read_csv('./MS_Initial_Data.csv', header=0))
Y = np.array(pd.read_csv('./Ydata.csv', header=0))
treatments = np.array(pd.read_csv('./MS_Initial_Data.csv', header=None))[0,2:]

PC9 = X[:,2]
Erl = X[:,3]
R428 = X[:,4]
Erl_R428 = X[:,5]
Erl_HGF = X[:,6]
Erl_FGF = X[:,7]
Erl_IGF = X[:,8]
KO_Erl = X[:,9]
KO_R428 = X[:,10]
KO_Erl_R428 = X[:,11]

# Variables: X phosphopeptides 
X = np.concatenate([PC9,Erl,R428,Erl_R428,Erl_HGF,Erl_FGF,Erl_IGF,KO_Erl,KO_R428,KO_Erl_R428])
X = np.reshape(X,(10,300)) 

# Observations: Y cell viability  (average between BR 3 and 4 at 72h)
Y_cv = Y[:,2]
Y_cv = Y_cv[:10]

# %%
X_F = FilteringOutPeptides(X)

# %%
maxt, mint = TunningHyperpar(X_F, Y_cv)
mint
# Out:
#    #Clusters #Components  std_test_scores  std_train_scores
# 0          2           2              0.0          0.031667
# 1          2           3              0.0          0.012404
# 2          2           4              0.0          0.001302
# 3          2           5              0.0          0.000110
# 4          2           6              0.0          0.000020
# 5          2           7              0.0          0.000002
# 6          2           8              0.0          0.000000
# 7          2           9              0.0          0.000000
# 8          2          10              0.0          0.000000
# 9          3           2              0.0          0.031667
# 10         3           3              0.0          0.012404
# 11         3           4              0.0          0.001302
# 12         3           5              0.0          0.000110
# 13         3           6              0.0          0.000020
# 14         3           7              0.0          0.000002
# 15         3           8              0.0          0.000000
# 16         3           9              0.0          0.000000
# 17         3          10              0.0          0.000000
# 18         4           2              0.0          0.031667
# 19         4           3              0.0          0.012404
# 20         4           4              0.0          0.001302
# 21         4           5              0.0          0.000110
# 22         4           6              0.0          0.000020
# 23         4           7              0.0          0.000002
# 24         4           8              0.0          0.000000
# 25         4           9              0.0          0.000000
# 26         4          10              0.0          0.000000
# 27         5           2              0.0          0.031667
# 28         5           3              0.0          0.012404
# 29         5           4              0.0          0.001302
# ..       ...         ...              ...               ...
# 51         7           8              0.0          0.000000
# 52         7           9              0.0          0.000000
# 53         7          10              0.0          0.000000
# 54         8           2              0.0          0.031667
# 55         8           3              0.0          0.012404
# 56         8           4              0.0          0.001302
# 57         8           5              0.0          0.000110
# 58         8           6              0.0          0.000020
# 59         8           7              0.0          0.000002
# 60         8           8              0.0          0.000000
# 61         8           9              0.0          0.000000
# 62         8          10              0.0          0.000000
# 63         9           2              0.0          0.031667
# 64         9           3              0.0          0.012404
# 65         9           4              0.0          0.001302
# 66         9           5              0.0          0.000110
# 67         9           6              0.0          0.000020
# 68         9           7              0.0          0.000002
# 69         9           8              0.0          0.000000
# 70         9           9              0.0          0.000000
# 71         9          10              0.0          0.000000
# 72        10           2              0.0          0.031667
# 73        10           3              0.0          0.012404
# 74        10           4              0.0          0.001302
# 75        10           5              0.0          0.000110
# 76        10           6              0.0          0.000020
# 77        10           7              0.0          0.000002
# 78        10           8              0.0          0.000000
# 79        10           9              0.0          0.000000
# 80        10          10              0.0          0.000000
#
# [81 rows x 4 columns]

# %%
regr = MyEstimator(5,2).fit(X_F,Y_cv)
X_cl = regr.transform(X_F)
PC1_scoresF, PC2_scoresF, PC1_xloadF, PC2_xloadF, PC1_yloadF, PC2_yloadF = regr.Scores_Loadings(X_cl,Y_cv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-0dc5e59ecad9> in <module>
#       1 regr = MyEstimator(5,2).fit(X_F,Y_cv)
#       2 X_cl = regr.transform(X_F)
# ----> 3 PC1_scoresF, PC2_scoresF, PC1_xloadF, PC2_xloadF, PC1_yloadF, PC2_yloadF = regr.Scores_Loadings(X_cl,Y_cv)
#
# ~/resistance-MS/Estimator.py in Scores_Loadings(self, X, Y)
#      46
#      47     def Scores_Loadings(self, X, Y):
# ---> 48         X_scores, Y_scores = self.plsr_.transform(X, Y)
#      49         PC1_scores, PC2_scores = X_scores[:,0], X_scores[:,1]
#      50         PC1_xload, PC2_xload = plsr.x_loadings_[:,0], plsr.x_loadings_[:,1]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/pls_.py in transform(self, X, Y, copy)
#     397         X = check_array(X, copy=copy, dtype=FLOAT_DTYPES)
#     398         # Normalize
# --> 399         X -= self.x_mean_
#     400         X /= self.x_std_
#     401         # Apply rotation
#
# ValueError: operands could not be broadcast together with shapes (10,5) (96,) (10,5)
